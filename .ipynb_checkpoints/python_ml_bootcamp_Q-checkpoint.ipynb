# %% [markdown]
# ## Part1: Data visualization

# %% [markdown]
# ### Step 1: Import pandas and numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2: Load region names (Data/ADNI/List_NamesOfRegions.csv)

# %%
df_region_name = pd.read_csv("./Data/ADNI/List_NamesOfRegions.csv")

# %%
df_region_name.head()
# Out:
#    ROI_INDEX    ROI_NAME
# 0        702         ICV
# 1        701  TOTALBRAIN
# 2        601          GM
# 3        604          WM
# 4        606        GM_L

# %% [markdown]
# ### Step 3: Load brain volumes (Data/ADNI/ADNI_BrainVolumes.csv)

# %%
df_brain_volumes = pd.read_csv("./Data/ADNI/ADNI_BrainVolumes.csv")

# %%
df_brain_volumes.head()
# Out:
#    ID           702           701            601            604  \
# 0   1  1.483889e+06  1.242659e+06  584259.696786  593055.786560
# 1   2  1.397874e+06  1.193265e+06  611098.838194  528088.857146
# 2   3  1.571713e+06  1.300427e+06  599035.861981  637024.633868
# 3   4  1.785075e+06  1.395203e+06  671843.252806  582753.668777
# 4   5  1.386439e+06  1.153623e+06  539974.138209  547297.880759
#
#              606            607            613            614           501  \
# 0  287082.643644  289687.720591  287688.033995  292001.703920  11366.362049
# 1  299281.430413  258060.149961  303685.791972  259086.357766  10942.349419
# 2  296004.241173  312828.608566  295158.382180  312072.397971  12123.627331
# 3  336478.502221  288573.470894  325163.798096  281681.077954  12499.119928
# 4  263924.731522  267504.337255  266393.752447  268997.773236  10795.770268
#
#    ...          198           199          200          201          202  \
# 0  ...  8057.808857   7321.637315  4164.959054  4079.529406  7783.590231
# 1  ...  9586.025433  11162.778434  7183.454640  5957.911505  6452.558433
# 2  ...  7297.379513   6589.684521  7574.762200  5597.224032  8418.511819
# 3  ...  9438.412306  10744.117350  7041.104096  6455.751673  6937.744569
# 4  ...  7243.586381   7402.844032  4052.105253  3701.949359  6714.133795
#
#            203          204          205          206          207
# 0  6707.809467  2134.686535  2577.655085   908.085527   986.132367
# 1  7376.461864  2268.625889  2143.118460  1103.199758   733.005576
# 2  9862.378354  2534.412917  2129.413100   988.241741  1014.608916
# 3  7258.370040  2168.440686  2208.518870  1077.892209  1530.353811
# 4  6586.516737  1783.474748  2357.224165   414.491766   672.889941
#
# [5 rows x 260 columns]

# %% [markdown]
# ### Step 4: Load demog&clin info (Data/ADNI/ADNI_DemogClin.csv)

# %%
df_demog = pd.read_csv("./Data/ADNI/ADNI_DemogClin.csv")

# %%
df_demog.head()
# Out:
#    SCID   Age Sex  Dx
# 0     1  84.8   M  CN
# 1     2  76.3   F  CN
# 2     3  79.3   M  CN
# 3     4  77.5   M  AD
# 4     5  89.6   F  CN

# %% [markdown]
# ### Step 5: Display diagnosis (Dx) types

# %%
df_demog.groupby(df_demog.Dx).describe()
# Out:
#       SCID                                                               Age  \
#      count        mean         std  min     25%    50%     75%    max  count
# Dx
# AD   191.0  402.848168  238.262401  4.0  193.00  408.0  603.50  802.0  191.0
# CN   228.0  400.758772  243.223450  1.0  177.50  417.5  605.50  812.0  228.0
# MCI  396.0  414.654040  229.817933  6.0  225.75  404.5  616.25  815.0  396.0
#
#
#           mean       std   min     25%   50%   75%   max
# Dx
# AD   75.295288  7.429516  55.1  70.800  75.8  80.7  90.9
# CN   75.871053  5.031316  59.9  72.275  75.6  78.5  89.6
# MCI  74.745960  7.405667  54.4  70.175  75.1  80.4  89.3

# %% [markdown]
# ### Step 6: Select only AD (Alzheimer Disease) and CN (Normal Control) subjects

# %%
select_group = ["AD","CN"]
select_AD_CN_df = df_demog.loc[df_demog.Dx.isin(select_group)]
select_AD_CN_df.head()
# Out:
#    SCID   Age Sex  Dx
# 0     1  84.8   M  CN
# 1     2  76.3   F  CN
# 2     3  79.3   M  CN
# 3     4  77.5   M  AD
# 4     5  89.6   F  CN

# %% [markdown]
# ### Step 7: Display summary stats of AD and CN demographics (functions groupby() and describe())

# %%
select_AD_CN_df.describe()
# Out:
#              SCID         Age
# count  419.000000  419.000000
# mean   401.711217   75.608592
# std    240.689520    6.238545
# min      1.000000   55.100000
# 25%    188.500000   71.600000
# 50%    417.000000   75.700000
# 75%    604.500000   79.800000
# max    812.000000   90.900000

# %% [markdown]
# ### Step 8: Replace "Sex" by a numeric var "IsF"

# %%
select_AD_CN_df = select_AD_CN_df.rename(columns={"Sex": "IsF"})
select_AD_CN_df['IsF'] = select_AD_CN_df['IsF'].apply(lambda x: 1 if x == "F" else 0)
select_AD_CN_df.head()
# Out:
#    SCID   Age  IsF  Dx
# 0     1  84.8    0  CN
# 1     2  76.3    1  CN
# 2     3  79.3    0  CN
# 3     4  77.5    0  AD
# 4     5  89.6    1  CN

# %% [markdown]
# ### Step 9: Replace "Dx" by a numeric var "IsAD"

# %%
select_AD_CN_df['Dx'] = select_AD_CN_df['Dx'].apply(lambda x: 1 if x == "AD" else 0)
select_AD_CN_df = select_AD_CN_df.rename(columns={"Dx": "IsAD"})
select_AD_CN_df.head()
# Out:
#    SCID   Age  IsF  IsAD
# 0     1  84.8    0     0
# 1     2  76.3    1     0
# 2     3  79.3    0     0
# 3     4  77.5    0     1
# 4     5  89.6    1     0

# %% [markdown]
# ### Step 10: Select few regions: Total brain, GM (gray matter), WM (white matter), Hippocampus

# %%
Select_group = ["TOTALBRAIN","GM","WM","Right Hippocampus"]
df_region_name_select = df_region_name.loc[df_region_name.ROI_NAME.isin(Select_group)]
df_region_name_select.head()
# Out:
#      ROI_INDEX           ROI_NAME
# 1          701         TOTALBRAIN
# 2          601                 GM
# 3          604                 WM
# 128         47  Right Hippocampus

# %% [markdown]
# ### Step 11: Merge selected volumes with Demographic data for AD/CN subjects ( function merge())

# %%
merage_df = df_brain_volumes.merge(select_AD_CN_df, left_on='ID', right_on='SCID')
merage_df.head()
# Out:
#    ID           702           701            601            604  \
# 0   1  1.483889e+06  1.242659e+06  584259.696786  593055.786560
# 1   2  1.397874e+06  1.193265e+06  611098.838194  528088.857146
# 2   3  1.571713e+06  1.300427e+06  599035.861981  637024.633868
# 3   4  1.785075e+06  1.395203e+06  671843.252806  582753.668777
# 4   5  1.386439e+06  1.153623e+06  539974.138209  547297.880759
#
#              606            607            613            614           501  \
# 0  287082.643644  289687.720591  287688.033995  292001.703920  11366.362049
# 1  299281.430413  258060.149961  303685.791972  259086.357766  10942.349419
# 2  296004.241173  312828.608566  295158.382180  312072.397971  12123.627331
# 3  336478.502221  288573.470894  325163.798096  281681.077954  12499.119928
# 4  263924.731522  267504.337255  266393.752447  268997.773236  10795.770268
#
#    ...          202          203          204          205          206  \
# 0  ...  7783.590231  6707.809467  2134.686535  2577.655085   908.085527
# 1  ...  6452.558433  7376.461864  2268.625889  2143.118460  1103.199758
# 2  ...  8418.511819  9862.378354  2534.412917  2129.413100   988.241741
# 3  ...  6937.744569  7258.370040  2168.440686  2208.518870  1077.892209
# 4  ...  6714.133795  6586.516737  1783.474748  2357.224165   414.491766
#
#            207  SCID   Age  IsF  IsAD
# 0   986.132367     1  84.8    0     0
# 1   733.005576     2  76.3    1     0
# 2  1014.608916     3  79.3    0     0
# 3  1530.353811     4  77.5    0     1
# 4   672.889941     5  89.6    1     0
#
# [5 rows x 264 columns]

# %% [markdown]
# ### Step 12: Display total brain volume across age for CN subjects (seaborn regplot or lmplot)

# %%
import seaborn

# %% [markdown]
# ### Step 13: Select only female subjects

# %%
select_AD_CN_df_F = select_AD_CN_df.loc[select_AD_CN_df["IsF"] == 1]
select_AD_CN_df_F.head()
# Out:
#     SCID   Age  IsF  IsAD
# 1      2  76.3    1     0
# 4      5  89.6    1     0
# 8      9  82.2    1     1
# 10    11  78.2    1     1
# 11    12  70.7    1     1

# %% [markdown]
# ### Step 14: Display total brain volume across age for female subjects for CN/AD

# %% [markdown]
# ### Step 15: Display GM volume across age for female subjects for CN/AD

# %% [markdown]
# ## Part 2: Machine Learning - A simple classification model

# %% [markdown]
# ### Step 16: Create a dataframe with only the ID column for AD and CN subjects

# %%
IDList = select_AD_CN_df["SCID"].tolist()

# %% [markdown]
# ### Step 17: Create a data frame with the IDs of selected subjects (function merge())

# %%
df_brain_volumes_select = df_brain_volumes.loc[df_brain_volumes.ID.isin(IDList)]
df_brain_volumes_select.head()
# Out:
#    ID           702           701            601            604  \
# 0   1  1.483889e+06  1.242659e+06  584259.696786  593055.786560
# 1   2  1.397874e+06  1.193265e+06  611098.838194  528088.857146
# 2   3  1.571713e+06  1.300427e+06  599035.861981  637024.633868
# 3   4  1.785075e+06  1.395203e+06  671843.252806  582753.668777
# 4   5  1.386439e+06  1.153623e+06  539974.138209  547297.880759
#
#              606            607            613            614           501  \
# 0  287082.643644  289687.720591  287688.033995  292001.703920  11366.362049
# 1  299281.430413  258060.149961  303685.791972  259086.357766  10942.349419
# 2  296004.241173  312828.608566  295158.382180  312072.397971  12123.627331
# 3  336478.502221  288573.470894  325163.798096  281681.077954  12499.119928
# 4  263924.731522  267504.337255  266393.752447  268997.773236  10795.770268
#
#    ...          198           199          200          201          202  \
# 0  ...  8057.808857   7321.637315  4164.959054  4079.529406  7783.590231
# 1  ...  9586.025433  11162.778434  7183.454640  5957.911505  6452.558433
# 2  ...  7297.379513   6589.684521  7574.762200  5597.224032  8418.511819
# 3  ...  9438.412306  10744.117350  7041.104096  6455.751673  6937.744569
# 4  ...  7243.586381   7402.844032  4052.105253  3701.949359  6714.133795
#
#            203          204          205          206          207
# 0  6707.809467  2134.686535  2577.655085   908.085527   986.132367
# 1  7376.461864  2268.625889  2143.118460  1103.199758   733.005576
# 2  9862.378354  2534.412917  2129.413100   988.241741  1014.608916
# 3  7258.370040  2168.440686  2208.518870  1077.892209  1530.353811
# 4  6586.516737  1783.474748  2357.224165   414.491766   672.889941
#
# [5 rows x 260 columns]

# %% [markdown]
# ### Step 18: Create X (brain volumes of selected subjects) and y (Dx labels of selected subjects)

# %% [markdown]
# ### Step 19: Load sklearn packages

# %%
from sklearn import svm
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import preprocessing

# %% [markdown]
# ### Step 20: Split data into train/test (60/40%)

# %% [markdown]
# ### Step 21: Scale data ( sklearn.preprocessing.StandardScaler)

# %% [markdown]
# ### Step 22: Train an SVM classifier using a linear kernel; train it using scaled training data

# %% [markdown]
# ### Step 23: Calculate predictions for the test set

# %% [markdown]
# ### Step 24: Calculate prediction accuracy
